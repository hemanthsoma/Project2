# %%
import pyspark
from pyspark import SparkContext
sc = SparkContext.getOrCreate();
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-LAPUB8T:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[2]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import pandas as pd
import tweepy

# %%
def printtweetdata(n, ith_tweet):
    print()
    print(f"Tweet {n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Following Count:{ith_tweet[1]}")
    print(f"Follower Count:{ith_tweet[2]}")
    print(f"Total Tweets:{ith_tweet[3]}")
    print(f"Retweet Count:{ith_tweet[4]}")

# %%
def scrape(words, date_since, numtweet):
    db = pd.DataFrame(columns=['username','following','followers', 'totaltweets', 'retweetcount'])
    tweets = tweepy.Cursor(api.search, q=words, lang="en",since=date_since, tweet_mode='extended').items(numtweet)
    list_tweets = [tweet for tweet in tweets]
    i = 1  
    for tweet in list_tweets:
        username = tweet.user.screen_name
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        ith_tweet = [username,following,followers,totaltweets, retweetcount]
        db.loc[len(db)] = ith_tweet
        printtweetdata(i, ith_tweet)
        i = i+1
    filename = 'ScrapedTweets.csv'
    db.to_csv(filename)

# %%
consumer_key = 'zsTrAIqVMAl6fMjd3aCnc243e'
consumer_secret = 'bezIY6xoFrQTVr0BYdinyyd8eVc60JNDaXMCWFXr3blfVZ9PV0'
access_key = '1059163618317606912-u4xy1i6vU5eptnQxnka9HXvz2eCNX6'
access_secret = 'YQFGmkCYKIyDLmMO4Nfw3iRjPAMY9E4MtfLacmgohOsSI'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
words = "ELon Musk"
date_since = "2020-08-10"
numtweet = 100

# %%
scrape(words, date_since, numtweet)
# Out:
# Tweet 1:
# Username:IlluminatiEyes
# Following Count:193
# Follower Count:9963
# Total Tweets:9324
# Retweet Count:0
#
# Tweet 2:
# Username:Tlotla15
# Following Count:2927
# Follower Count:1246
# Total Tweets:63101
# Retweet Count:74
#
# Tweet 3:
# Username:avishagrawal
# Following Count:800
# Follower Count:114
# Total Tweets:2503
# Retweet Count:4
#
# Tweet 4:
# Username:TheRealestEazy
# Following Count:906
# Follower Count:246
# Total Tweets:31473
# Retweet Count:52
#
# Tweet 5:
# Username:HanifAl23200435
# Following Count:693
# Follower Count:27
# Total Tweets:1532
# Retweet Count:2395
#
# Tweet 6:
# Username:MakoriGeorge_
# Following Count:2456
# Follower Count:1959
# Total Tweets:62628
# Retweet Count:384
#
# Tweet 7:
# Username:LonElliott
# Following Count:373
# Follower Count:80
# Total Tweets:5304
# Retweet Count:0
#
# Tweet 8:
# Username:tendaimadondo
# Following Count:2043
# Follower Count:2737
# Total Tweets:5921
# Retweet Count:1
#
# Tweet 9:
# Username:MichaelPetilli
# Following Count:4321
# Follower Count:432
# Total Tweets:20972
# Retweet Count:52
#
# Tweet 10:
# Username:Penny_Puncher
# Following Count:559
# Follower Count:143
# Total Tweets:75
# Retweet Count:22
#
# Tweet 11:
# Username:Que2Stacy
# Following Count:3605
# Follower Count:2594
# Total Tweets:9511
# Retweet Count:564
#
# Tweet 12:
# Username:cyclometricus
# Following Count:209
# Follower Count:101
# Total Tweets:2642
# Retweet Count:0
#
# Tweet 13:
# Username:y_permatamora
# Following Count:575
# Follower Count:786
# Total Tweets:30333
# Retweet Count:525
#
# Tweet 14:
# Username:pistoltart
# Following Count:95
# Follower Count:41
# Total Tweets:17873
# Retweet Count:862
#
# Tweet 15:
# Username:JosRoja98749695
# Following Count:79
# Follower Count:19
# Total Tweets:1129
# Retweet Count:564
#
# Tweet 16:
# Username:HoumanRaeissi
# Following Count:15
# Follower Count:0
# Total Tweets:14
# Retweet Count:2395
#
# Tweet 17:
# Username:Zuli65583833
# Following Count:3
# Follower Count:2
# Total Tweets:59
# Retweet Count:236
#
# Tweet 18:
# Username:henricaralhu
# Following Count:352
# Follower Count:84
# Total Tweets:2802
# Retweet Count:0
#
# Tweet 19:
# Username:ShyIsDry
# Following Count:766
# Follower Count:270
# Total Tweets:36901
# Retweet Count:74
#
# Tweet 20:
# Username:robertinha_ct
# Following Count:32
# Follower Count:38
# Total Tweets:27
# Retweet Count:0
#
# Tweet 21:
# Username:janfortfc
# Following Count:116
# Follower Count:51
# Total Tweets:4984
# Retweet Count:0
#
# Tweet 22:
# Username:KwameTornyo
# Following Count:4069
# Follower Count:866
# Total Tweets:21284
# Retweet Count:27
#
# Tweet 23:
# Username:vanthan03279526
# Following Count:1903
# Follower Count:122
# Total Tweets:3462
# Retweet Count:2395
#
# Tweet 24:
# Username:RetroGamer71
# Following Count:521
# Follower Count:268
# Total Tweets:7813
# Retweet Count:0
#
# Tweet 25:
# Username:Stonk32428782
# Following Count:1617
# Follower Count:2923
# Total Tweets:8242
# Retweet Count:31
#
# Tweet 26:
# Username:Michell37663054
# Following Count:0
# Follower Count:0
# Total Tweets:74
# Retweet Count:0
#
# Tweet 27:
# Username:Rakesh06375688
# Following Count:2564
# Follower Count:205
# Total Tweets:1275
# Retweet Count:525
#
# Tweet 28:
# Username:ryusei_purple
# Following Count:2121
# Follower Count:199
# Total Tweets:69438
# Retweet Count:0
#
# Tweet 29:
# Username:infopap
# Following Count:682
# Follower Count:719
# Total Tweets:35436
# Retweet Count:6
#
# Tweet 30:
# Username:OneilRoses
# Following Count:149
# Follower Count:73
# Total Tweets:60469
# Retweet Count:862
#
# Tweet 31:
# Username:AttrRadio
# Following Count:18
# Follower Count:54
# Total Tweets:16861
# Retweet Count:0
#
# Tweet 32:
# Username:HonchoKevo
# Following Count:1059
# Follower Count:1480
# Total Tweets:14739
# Retweet Count:74
#
# Tweet 33:
# Username:Fede_bq
# Following Count:93
# Follower Count:93
# Total Tweets:1438
# Retweet Count:0
#
# Tweet 34:
# Username:thebifurious
# Following Count:276
# Follower Count:48
# Total Tweets:1848
# Retweet Count:0
#
# Tweet 35:
# Username:EndlessSpazz
# Following Count:298
# Follower Count:65
# Total Tweets:4793
# Retweet Count:0
#
# Tweet 36:
# Username:ernieschell
# Following Count:13581
# Follower Count:12478
# Total Tweets:236199
# Retweet Count:1
#
# Tweet 37:
# Username:bluesky4331
# Following Count:30
# Follower Count:1
# Total Tweets:1
# Retweet Count:0
#
# Tweet 38:
# Username:oneofonejayy
# Following Count:373
# Follower Count:415
# Total Tweets:3833
# Retweet Count:0
#
# Tweet 39:
# Username:FaizanSaif21
# Following Count:111
# Follower Count:113
# Total Tweets:15134
# Retweet Count:0
#
# Tweet 40:
# Username:Siddhi_Sabne
# Following Count:2753
# Follower Count:121
# Total Tweets:1432
# Retweet Count:4
#
# Tweet 41:
# Username:loserfromks
# Following Count:869
# Follower Count:490
# Total Tweets:12738
# Retweet Count:0
#
# Tweet 42:
# Username:michaeldhegge
# Following Count:2321
# Follower Count:216
# Total Tweets:20471
# Retweet Count:1
#
# Tweet 43:
# Username:ZULKARN99358749
# Following Count:44
# Follower Count:1
# Total Tweets:36
# Retweet Count:2395
#
# Tweet 44:
# Username:corylittlejohn6
# Following Count:30
# Follower Count:10
# Total Tweets:831
# Retweet Count:10
#
# Tweet 45:
# Username:AllMediaLies76
# Following Count:280
# Follower Count:210
# Total Tweets:7233
# Retweet Count:22
#
# Tweet 46:
# Username:corylittlejohn6
# Following Count:30
# Follower Count:10
# Total Tweets:831
# Retweet Count:6
#
# Tweet 47:
# Username:Mikky0019
# Following Count:123
# Follower Count:103
# Total Tweets:591
# Retweet Count:74
#
# Tweet 48:
# Username:VSlyth
# Following Count:231
# Follower Count:352
# Total Tweets:14446
# Retweet Count:52
#
# Tweet 49:
# Username:iyerishcoffee
# Following Count:1239
# Follower Count:788
# Total Tweets:11827
# Retweet Count:525
#
# Tweet 50:
# Username:EveryoneSaysHi1
# Following Count:5000
# Follower Count:928
# Total Tweets:51999
# Retweet Count:0
#
# Tweet 51:
# Username:mrekkosu
# Following Count:770
# Follower Count:42780
# Total Tweets:2334
# Retweet Count:0
#
# Tweet 52:
# Username:tetoroa
# Following Count:509
# Follower Count:126
# Total Tweets:27480
# Retweet Count:7
#
# Tweet 53:
# Username:mygeex
# Following Count:807
# Follower Count:403
# Total Tweets:3155
# Retweet Count:0
#
# Tweet 54:
# Username:Narakeriss
# Following Count:542
# Follower Count:162
# Total Tweets:14883
# Retweet Count:0
#
# Tweet 55:
# Username:adrianff87
# Following Count:447
# Follower Count:72
# Total Tweets:1735
# Retweet Count:20
#
# Tweet 56:
# Username:Christi01402555
# Following Count:728
# Follower Count:205
# Total Tweets:4453
# Retweet Count:564
#
# Tweet 57:
# Username:carlosacifuen
# Following Count:343
# Follower Count:89
# Total Tweets:15
# Retweet Count:862
#
# Tweet 58:
# Username:Scarlet__Bliss
# Following Count:4150
# Follower Count:203
# Total Tweets:26534
# Retweet Count:52
#
# Tweet 59:
# Username:janhopi
# Following Count:682
# Follower Count:594
# Total Tweets:10582
# Retweet Count:0
#
# Tweet 60:
# Username:ChadHan96679211
# Following Count:33
# Follower Count:7
# Total Tweets:438
# Retweet Count:6
#
# Tweet 61:
# Username:TokyoDurifto
# Following Count:351
# Follower Count:522
# Total Tweets:1442
# Retweet Count:0
#
# Tweet 62:
# Username:Jasgagger
# Following Count:4896
# Follower Count:813
# Total Tweets:79200
# Retweet Count:0
#
# Tweet 63:
# Username:mikewhitmore
# Following Count:80366
# Follower Count:93816
# Total Tweets:89095
# Retweet Count:1
#
# Tweet 64:
# Username:shenuque
# Following Count:565
# Follower Count:576
# Total Tweets:2573
# Retweet Count:0
#
# Tweet 65:
# Username:LukePersaud
# Following Count:1059
# Follower Count:1563
# Total Tweets:10663
# Retweet Count:73
#
# Tweet 66:
# Username:carlottascorner
# Following Count:479
# Follower Count:287
# Total Tweets:51939
# Retweet Count:0
#
# Tweet 67:
# Username:PrightonD
# Following Count:767
# Follower Count:358
# Total Tweets:115803
# Retweet Count:7
#
# Tweet 68:
# Username:jdbeaty
# Following Count:102
# Follower Count:37
# Total Tweets:191
# Retweet Count:10
#
# Tweet 69:
# Username:defiunicorn
# Following Count:805
# Follower Count:807
# Total Tweets:5769
# Retweet Count:13
#
# Tweet 70:
# Username:biancadellaware
# Following Count:159
# Follower Count:54
# Total Tweets:423
# Retweet Count:0
#
# Tweet 71:
# Username:USAjobs2021
# Following Count:1039
# Follower Count:1198
# Total Tweets:238457
# Retweet Count:52
#
# Tweet 72:
# Username:JoeKelleyComedy
# Following Count:313
# Follower Count:219
# Total Tweets:2242
# Retweet Count:0
#
# Tweet 73:
# Username:PLUGSRUS
# Following Count:211
# Follower Count:367
# Total Tweets:47010
# Retweet Count:0
#
# Tweet 74:
# Username:AnaaCrane
# Following Count:195
# Follower Count:72
# Total Tweets:2614
# Retweet Count:0
#
# Tweet 75:
# Username:AspyHC
# Following Count:2363
# Follower Count:301
# Total Tweets:73114
# Retweet Count:52
#
# Tweet 76:
# Username:Crypto_Miner86
# Following Count:213
# Follower Count:27
# Total Tweets:675
# Retweet Count:10
#
# Tweet 77:
# Username:MRintouch
# Following Count:1602
# Follower Count:1244
# Total Tweets:113207
# Retweet Count:115
#
# Tweet 78:
# Username:wed3009
# Following Count:361
# Follower Count:31
# Total Tweets:3689
# Retweet Count:52
#
# Tweet 79:
# Username:Wangenstein
# Following Count:2882
# Follower Count:3082
# Total Tweets:229915
# Retweet Count:52
#
# Tweet 80:
# Username:jem_demon
# Following Count:572
# Follower Count:218
# Total Tweets:13386
# Retweet Count:74
#
# Tweet 81:
# Username:cemcomery
# Following Count:79
# Follower Count:10
# Total Tweets:511
# Retweet Count:52
#
# Tweet 82:
# Username:DreaTheReal
# Following Count:2143
# Follower Count:1595
# Total Tweets:67958
# Retweet Count:115
#
# Tweet 83:
# Username:TerriTucker6262
# Following Count:158
# Follower Count:153
# Total Tweets:8621
# Retweet Count:10
#
# Tweet 84:
# Username:itslucyk
# Following Count:674
# Follower Count:202
# Total Tweets:3602
# Retweet Count:1
#
# Tweet 85:
# Username:NnkrumahSocrate
# Following Count:299
# Follower Count:213
# Total Tweets:33556
# Retweet Count:52
#
# Tweet 86:
# Username:Sampson82857277
# Following Count:16
# Follower Count:0
# Total Tweets:35
# Retweet Count:137
#
# Tweet 87:
# Username:dogesuppporteam
# Following Count:778
# Follower Count:989
# Total Tweets:12463
# Retweet Count:10
#
# Tweet 88:
# Username:Sampson82857277
# Following Count:16
# Follower Count:0
# Total Tweets:35
# Retweet Count:149
#
# Tweet 89:
# Username:NoobApologist
# Following Count:419
# Follower Count:456
# Total Tweets:8569
# Retweet Count:0
#
# Tweet 90:
# Username:Sampson82857277
# Following Count:16
# Follower Count:0
# Total Tweets:35
# Retweet Count:138
#
# Tweet 91:
# Username:TerriTucker6262
# Following Count:158
# Follower Count:153
# Total Tweets:8621
# Retweet Count:6
#
# Tweet 92:
# Username:DogeCoin_Gang
# Following Count:30
# Follower Count:9
# Total Tweets:131
# Retweet Count:10
#
# Tweet 93:
# Username:Sampson82857277
# Following Count:16
# Follower Count:0
# Total Tweets:35
# Retweet Count:181
#
# Tweet 94:
# Username:aCreole
# Following Count:836
# Follower Count:1771
# Total Tweets:81404
# Retweet Count:862
#
# Tweet 95:
# Username:Sheyii_Best
# Following Count:699
# Follower Count:903
# Total Tweets:38135
# Retweet Count:74
#
# Tweet 96:
# Username:Sampson82857277
# Following Count:16
# Follower Count:0
# Total Tweets:35
# Retweet Count:303
#
# Tweet 97:
# Username:TSubramamian
# Following Count:166
# Follower Count:5
# Total Tweets:70
# Retweet Count:525
#
# Tweet 98:
# Username:Sampson82857277
# Following Count:16
# Follower Count:0
# Total Tweets:35
# Retweet Count:418
#
# Tweet 99:
# Username:TownesG2
# Following Count:160
# Follower Count:65
# Total Tweets:1704
# Retweet Count:10
#
# Tweet 100:
# Username:Crawdad76268324
# Following Count:1336
# Follower Count:523
# Total Tweets:34152
# Retweet Count:862
